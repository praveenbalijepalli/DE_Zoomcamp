# %% [markdown]
# ## Week 2 Homework
#
# The goal of this homework is to familiarise users with workflow orchestration and observation.

# %% [markdown]
# ## Question 1. Load January 2020 data
#
# Using the `etl_web_to_gcs.py` flow that loads taxi data into GCS as a guide, create a flow that loads the green taxi CSV dataset for January 2020 into GCS and run it. Look at the logs to find out how many rows the dataset has.
#
# How many rows does that dataset have?
#
# * **447,770**
# * 766,792
# * 299,234
# * 822,132

# %%
"""etl_web_to_gcs.py or you can use !python etl_web_to_gcs.py in the terminal to get the list of rows"""
from pathlib import Path
import pandas as pd
from prefect import flow, task
from prefect_gcp.cloud_storage import GcsBucket
from random import randint


@task(retries=3)
def fetch(dataset_url: str) -> pd.DataFrame:
    """Read taxi data from web into pandas DataFrame"""
    # if randint(0, 1) > 0:
    #     raise Exception

    df = pd.read_csv(dataset_url)
    return df


@task(log_prints=True)
def clean(df: pd.DataFrame) -> pd.DataFrame:
    """Fix dtype issues"""
    df["lpep_pickup_datetime"] = pd.to_datetime(df["lpep_pickup_datetime"])
    df["lpep_dropoff_datetime"] = pd.to_datetime(df["lpep_dropoff_datetime"])
    print(df.head(2))
    print(f"columns: {df.dtypes}")
    print(f"rows: {len(df)}")
    return df


@task()
def write_local(df: pd.DataFrame, color: str, dataset_file: str) -> Path:
    """Write DataFrame out locally as parquet file"""
    Path(f"data/{color}").mkdir(parents=True, exist_ok=True)
    path = Path(f"data/{color}/{dataset_file}.parquet")
    df.to_parquet(path, compression="gzip")
    return path


@flow()
def etl_web_to_gcs() -> None:
    """The main ETL function"""
    color = "green"
    year = 2020
    month = 1
    dataset_file = f"{color}_tripdata_{year}-{month:02}"
    dataset_url = f"https://github.com/DataTalksClub/nyc-tlc-data/releases/download/{color}/{dataset_file}.csv.gz"

    df = fetch(dataset_url)
    df_clean = clean(df)
    path = write_local(df_clean, color, dataset_file)


if __name__ == "__main__":
    etl_web_to_gcs()
# Out:
# C:\anaconda3\envs\DPhi-DE\lib\site-packages\prefect\tasks.py:261: UserWarning: A task named 'fetch' and defined at 'C:\Users\Praveen\AppData\Local\Temp\ipykernel_25848\2090947012.py:8' conflicts with another task. Consider specifying a unique `name` parameter in the task definition:
#
#  `@task(name='my_unique_name', ...)`
#   warnings.warn(
# C:\anaconda3\envs\DPhi-DE\lib\site-packages\prefect\tasks.py:261: UserWarning: A task named 'clean' and defined at 'C:\Users\Praveen\AppData\Local\Temp\ipykernel_25848\2090947012.py:18' conflicts with another task. Consider specifying a unique `name` parameter in the task definition:
#
#  `@task(name='my_unique_name', ...)`
#   warnings.warn(
# C:\anaconda3\envs\DPhi-DE\lib\site-packages\prefect\tasks.py:261: UserWarning: A task named 'write_local' and defined at 'C:\Users\Praveen\AppData\Local\Temp\ipykernel_25848\2090947012.py:31' conflicts with another task. Consider specifying a unique `name` parameter in the task definition:
#
#  `@task(name='my_unique_name', ...)`
#   warnings.warn(
# C:\anaconda3\envs\DPhi-DE\lib\site-packages\prefect\flows.py:206: UserWarning: A flow named 'etl-web-to-gcs' and defined at 'C:\Users\Praveen\AppData\Local\Temp\ipykernel_25848\2090947012.py:40' conflicts with another flow. Consider specifying a unique `name` parameter in the flow definition:
#
#  `@flow(name='my_unique_name', ...)`
#   warnings.warn(
# 00:19:47.107 | INFO    | prefect.engine - Created flow run 'authentic-grebe' for flow 'etl-web-to-gcs'
# 00:19:47.373 | INFO    | Flow run 'authentic-grebe' - Created task run 'fetch-0' for task 'fetch'
# 00:19:47.375 | INFO    | Flow run 'authentic-grebe' - Executing 'fetch-0' immediately...
# C:\Users\Praveen\AppData\Local\Temp\ipykernel_25848\2090947012.py:14: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(dataset_url)
# 00:19:58.579 | INFO    | Task run 'fetch-0' - Finished in state Completed()
# 00:19:58.640 | INFO    | Flow run 'authentic-grebe' - Created task run 'clean-0' for task 'clean'
# 00:19:58.642 | INFO    | Flow run 'authentic-grebe' - Executing 'clean-0' immediately...
# 00:19:59.376 | INFO    | Task run 'clean-0' -    VendorID store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 0       2.0                  N         1.0           264           264
# 1       2.0                  N         5.0            66            65
#
#    passenger_count  trip_distance  fare_amount  extra  mta_tax  tip_amount  \
# 0              5.0           0.00          3.5    0.5      0.5        0.01
# 1              2.0           1.28         20.0    0.0      0.0        4.06
#
#    tolls_amount  ehail_fee  improvement_surcharge  total_amount  payment_type  \
# 0           0.0        NaN                    0.3          4.81           1.0
# 1           0.0        NaN                    0.3         24.36           1.0
#
#    trip_type  congestion_surcharge tpep_pickup_datetime tpep_dropoff_datetime
# 0        1.0                   0.0  2019-12-18 15:52:30   2019-12-18 15:54:39
# 1        2.0                   0.0  2020-01-01 00:45:58   2020-01-01 00:56:39
# 00:19:59.381 | INFO    | Task run 'clean-0' - columns: VendorID                        float64
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                      int64
# DOLocationID                      int64
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                       float64
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# tpep_pickup_datetime     datetime64[ns]
# tpep_dropoff_datetime    datetime64[ns]
# dtype: object
# 00:19:59.385 | INFO    | Task run 'clean-0' - rows: 447770
# 00:19:59.430 | INFO    | Task run 'clean-0' - Finished in state Completed()
# 00:19:59.476 | INFO    | Flow run 'authentic-grebe' - Created task run 'write_local-0' for task 'write_local'
# 00:19:59.478 | INFO    | Flow run 'authentic-grebe' - Executing 'write_local-0' immediately...
# 00:20:01.136 | INFO    | Task run 'write_local-0' - Finished in state Completed()
# 00:20:01.183 | INFO    | Flow run 'authentic-grebe' - Finished in state Completed('All states completed.')

# %% [markdown]
# ## Question 2. Scheduling with Cron
#
# Cron is a common scheduling specification for workflows.
#
# Using the flow in `etl_web_to_gcs.py`, create a deployment to run on the first of every month at 5am UTC. What’s the cron schedule for that?
#
# - **`0 5 1 * *`**
# - `0 0 5 1 *`
# - `5 * 1 0 *`
# - `* * 5 1 0`

# %% [markdown]
#  ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 3. Loading data to BigQuery
#
# Using `etl_gcs_to_bq.py` as a starting point, modify the script for extracting data from GCS and loading it into BigQuery. This new script should not fill or remove rows with missing values. (The script is really just doing the E and L parts of ETL).
#
# The main flow should print the total number of rows processed by the script. Set the flow decorator to log the print statement.
#
# Parametrize the entrypoint flow to accept a list of months, a year, and a taxi color.
#
# Make any other necessary changes to the code for it to function as required.
#
# Create a deployment for this flow to run in a local subprocess with local flow code storage (the defaults).
#
# Make sure you have the parquet data files for Yellow taxi data for Feb. 2019 and March 2019 loaded in GCS. Run your deployment to append this data to your BiqQuery table. How many rows did your flow code process?
#
# - **14,851,920**
# - 12,282,990
# - 27,235,753
# - 11,338,483

# %% [markdown]
# ***Run the following commands for this question***
#
# !python etl_web_to_gcs_2019_2_3_q3.py # To load data to GCS
#
# !python etl_gcs_to_bq_parameterized_q3.py # To load data to Bigquery from GCS

# %% [markdown]
# Result:
# ![image.png](attachment:image.png)

# %% [markdown]
#  ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ***Deployment for this flow.<br>
# Refer to etl_parent_flow-deployment.yaml file in the Week2/week_2_workflow_orchestration folder.***
# ![image-2.png](attachment:image-2.png)
# <br>
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Question 4. Github Storage Block
#
# Using the `web_to_gcs` script from the videos as a guide, you want to store your flow code in a GitHub repository for collaboration with your team. Prefect can look in the GitHub repo to find your flow code and read it. Create a GitHub storage block from the UI or in Python code and use that in your Deployment instead of storing your flow code locally or baking your flow code into a Docker image.
#
# Note that you will have to push your code to GitHub, Prefect will not push it for you.
#
# Run your deployment in a local subprocess (the default if you don’t specify an infrastructure). Use the Green taxi data for the month of November 2020.
#
# How many rows were processed by the script?
#
# - 88,019
# - 192,297
# - **88,605**
# - 190,225

# %%
# !python etl_web_to_gcs_q4.py
# Out:
# 00:53:09.417 | INFO    | prefect.engine - Created flow run 'illegal-hoatzin' for flow 'etl-web-to-gcs-q4'
# 00:53:09.718 | INFO    | Flow run 'illegal-hoatzin' - Created task run 'fetch-0' for task 'fetch'
# 00:53:09.720 | INFO    | Flow run 'illegal-hoatzin' - Executing 'fetch-0' immediately...
# C:\Users\Praveen\Desktop\DE-zoomcamp\cohorts\2023\Week2\week_2_workflow_orchestration\etl_web_to_gcs_q4.py:14: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(dataset_url)
# 00:53:12.512 | INFO    | Task run 'fetch-0' - Finished in state Completed()
# 00:53:12.564 | INFO    | Flow run 'illegal-hoatzin' - Created task run 'clean-0' for task 'clean'
# 00:53:12.565 | INFO    | Flow run 'illegal-hoatzin' - Executing 'clean-0' immediately...
# 00:53:12.800 | INFO    | Task run 'clean-0' -    VendorID lpep_pickup_datetime  ... trip_type congestion_surcharge
# 0       2.0  2020-11-01 00:08:23  ...       1.0                 2.75
# 1       2.0  2020-11-01 00:23:32  ...       1.0                 0.00
#
# [2 rows x 20 columns]
# 00:53:12.803 | INFO    | Task run 'clean-0' - columns: VendorID                        float64
# lpep_pickup_datetime     datetime64[ns]
# lpep_dropoff_datetime    datetime64[ns]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                      int64
# DOLocationID                      int64
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                       float64
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# dtype: object
# 00:53:12.804 | INFO    | Task run 'clean-0' - rows: 88605
# 00:53:12.841 | INFO    | Task run 'clean-0' - Finished in state Completed()
# 00:53:12.885 | INFO    | Flow run 'illegal-hoatzin' - Created task run 'write_local-0' for task 'write_local'
# 00:53:12.886 | INFO    | Flow run 'illegal-hoatzin' - Executing 'write_local-0' immediately...
# 00:53:13.279 | INFO    | Task run 'write_local-0' - Finished in state Completed()
# 00:53:13.317 | INFO    | Flow run 'illegal-hoatzin' - Created task run 'write_gcs-0' for task 'write_gcs'
# 00:53:13.317 | INFO    | Flow run 'illegal-hoatzin' - Executing 'write_gcs-0' immediately...
# 00:53:13.426 | INFO    | Task run 'write_gcs-0' - Getting bucket 'prefect-dezoomcamp-bucket'.
# 00:53:14.268 | INFO    | Task run 'write_gcs-0' - Uploading from WindowsPath('data/green/green_tripdata_2020-11.parquet') to the bucket 'prefect-dezoomcamp-bucket' path 'data\\green\\green_tripdata_2020-11.parquet'.
# 00:53:15.489 | INFO    | Task run 'write_gcs-0' - Finished in state Completed()
# 00:53:15.530 | INFO    | Flow run 'illegal-hoatzin' - Finished in state Completed('All states completed.')
# 00:53:22.477 | INFO    | prefect.engine - Created flow run 'singing-angelfish' for flow 'etl-web-to-gcs-q4'
# 00:53:22.752 | INFO    | Flow run 'singing-angelfish' - Created task run 'fetch-0' for task 'fetch'
# 00:53:22.754 | INFO    | Flow run 'singing-angelfish' - Executing 'fetch-0' immediately...
# C:\Users\Praveen\Desktop\DE-zoomcamp\cohorts\2023\Week2\week_2_workflow_orchestration\etl_web_to_gcs_q4.py:14: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(dataset_url)
# 00:53:25.003 | INFO    | Task run 'fetch-0' - Finished in state Completed()
# 00:53:25.056 | INFO    | Flow run 'singing-angelfish' - Created task run 'clean-0' for task 'clean'
# 00:53:25.057 | INFO    | Flow run 'singing-angelfish' - Executing 'clean-0' immediately...
# 00:53:25.293 | INFO    | Task run 'clean-0' -    VendorID lpep_pickup_datetime  ... trip_type congestion_surcharge
# 0       2.0  2020-11-01 00:08:23  ...       1.0                 2.75
# 1       2.0  2020-11-01 00:23:32  ...       1.0                 0.00
#
# [2 rows x 20 columns]
# 00:53:25.294 | INFO    | Task run 'clean-0' - columns: VendorID                        float64
# lpep_pickup_datetime     datetime64[ns]
# lpep_dropoff_datetime    datetime64[ns]
# store_and_fwd_flag               object
# RatecodeID                      float64
# PULocationID                      int64
# DOLocationID                      int64
# passenger_count                 float64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                       float64
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                    float64
# trip_type                       float64
# congestion_surcharge            float64
# dtype: object
# 00:53:25.296 | INFO    | Task run 'clean-0' - rows: 88605
# 00:53:25.329 | INFO    | Task run 'clean-0' - Finished in state Completed()
# 00:53:25.367 | INFO    | Flow run 'singing-angelfish' - Created task run 'write_local-0' for task 'write_local'
# 00:53:25.368 | INFO    | Flow run 'singing-angelfish' - Executing 'write_local-0' immediately...
# 00:53:25.743 | INFO    | Task run 'write_local-0' - Finished in state Completed()
# 00:53:25.787 | INFO    | Flow run 'singing-angelfish' - Created task run 'write_gcs-0' for task 'write_gcs'
# 00:53:25.788 | INFO    | Flow run 'singing-angelfish' - Executing 'write_gcs-0' immediately...
# 00:53:25.894 | INFO    | Task run 'write_gcs-0' - Getting bucket 'prefect-dezoomcamp-bucket'.
# 00:53:26.723 | INFO    | Task run 'write_gcs-0' - Uploading from WindowsPath('data/green/green_tripdata_2020-11.parquet') to the bucket 'prefect-dezoomcamp-bucket' path 'data\\green\\green_tripdata_2020-11.parquet'.
# 00:53:28.573 | INFO    | Task run 'write_gcs-0' - Finished in state Completed()
# 00:53:28.616 | INFO    | Flow run 'singing-angelfish' - Finished in state Completed('All states completed.')

# %% [markdown]
# ## Question 5. Email or Slack notifications
#
# Q5. It’s often helpful to be notified when something with your dataflow doesn’t work as planned. Choose one of the options below for creating email or slack notifications.
#
# The hosted Prefect Cloud lets you avoid running your own server and has Automations that allow you to get notifications when certain events occur or don’t occur.
#
# Create a free forever Prefect Cloud account at app.prefect.cloud and connect your workspace to it following the steps in the UI when you sign up.
#
# Set up an Automation that will send yourself an email when a flow run completes. Run the deployment used in Q4 for the Green taxi data for April 2019. Check your email to see the notification.
#
# Alternatively, use a Prefect Cloud Automation or a self-hosted Orion server Notification to get notifications in a Slack workspace via an incoming webhook.
#
# Join my temporary Slack workspace with [this link](https://join.slack.com/t/temp-notify/shared_invite/zt-1odklt4wh-hH~b89HN8MjMrPGEaOlxIw). 400 people can use this link and it expires in 90 days.
#
# In the Prefect Cloud UI create an [Automation](https://docs.prefect.io/ui/automations) or in the Prefect Orion UI create a [Notification](https://docs.prefect.io/ui/notifications/) to send a Slack message when a flow run enters a Completed state. Here is the Webhook URL to use: https://hooks.slack.com/services/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
#
# Test the functionality.
#
# Alternatively, you can grab the webhook URL from your own Slack workspace and Slack App that you create.
#
#
# How many rows were processed by the script?
#
# - `125,268`
# - `377,922`
# - `728,390`
# - **`514,392`**

# %%
# !python etl_web_to_gcs_q5.py
# Out:
# 02:01:41.946 | INFO    | prefect.engine - Created flow run 'neon-dragonfly' for flow 'etl-web-to-gcs-q5'
# 02:01:42.232 | INFO    | Flow run 'neon-dragonfly' - Created task run 'fetch-0' for task 'fetch'
# 02:01:42.234 | INFO    | Flow run 'neon-dragonfly' - Executing 'fetch-0' immediately...
# 02:01:49.145 | INFO    | Task run 'fetch-0' - Finished in state Completed()
# 02:01:49.208 | INFO    | Flow run 'neon-dragonfly' - Created task run 'clean-0' for task 'clean'
# 02:01:49.209 | INFO    | Flow run 'neon-dragonfly' - Executing 'clean-0' immediately...
# 02:01:50.070 | INFO    | Task run 'clean-0' -    VendorID lpep_pickup_datetime  ... trip_type congestion_surcharge
# 0         2  2019-04-01 00:18:40  ...         1                 2.75
# 1         2  2019-04-01 00:18:24  ...         1                 0.00
#
# [2 rows x 20 columns]
# 02:01:50.072 | INFO    | Task run 'clean-0' - columns: VendorID                          int64
# lpep_pickup_datetime     datetime64[ns]
# lpep_dropoff_datetime    datetime64[ns]
# store_and_fwd_flag               object
# RatecodeID                        int64
# PULocationID                      int64
# DOLocationID                      int64
# passenger_count                   int64
# trip_distance                   float64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# ehail_fee                       float64
# improvement_surcharge           float64
# total_amount                    float64
# payment_type                      int64
# trip_type                         int64
# congestion_surcharge            float64
# dtype: object
# 02:01:50.074 | INFO    | Task run 'clean-0' - rows: 514392
# 02:01:50.110 | INFO    | Task run 'clean-0' - Finished in state Completed()
# 02:01:50.149 | INFO    | Flow run 'neon-dragonfly' - Created task run 'write_local-0' for task 'write_local'
# 02:01:50.150 | INFO    | Flow run 'neon-dragonfly' - Executing 'write_local-0' immediately...
# 02:01:52.028 | INFO    | Task run 'write_local-0' - Finished in state Completed()
# 02:01:52.072 | INFO    | Flow run 'neon-dragonfly' - Created task run 'write_gcs-0' for task 'write_gcs'
# 02:01:52.073 | INFO    | Flow run 'neon-dragonfly' - Executing 'write_gcs-0' immediately...
# 02:01:52.175 | INFO    | Task run 'write_gcs-0' - Getting bucket 'prefect-dezoomcamp-bucket'.
# 02:01:53.136 | INFO    | Task run 'write_gcs-0' - Uploading from WindowsPath('data/green/green_tripdata_2019-04.parquet') to the bucket 'prefect-dezoomcamp-bucket' path 'data\\green\\green_tripdata_2019-04.parquet'.
# 02:01:57.693 | INFO    | Task run 'write_gcs-0' - Finished in state Completed()
# 02:01:57.736 | INFO    | Flow run 'neon-dragonfly' - Finished in state Completed('All states completed.')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Question 6. Secrets
#
# Prefect Secret blocks provide secure, encrypted storage in the database and obfuscation in the UI. Create a secret block in the UI that stores a fake 10-digit password to connect to a third-party service. Once you’ve created your block in the UI, how many characters are shown as asterisks (*) on the next page of the UI?
#
# - 5
# - 6
# - **8**
# - 10

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Submitting the solutions
#
# * Form for submitting: https://forms.gle/PY8mBEGXJ1RvmTM97
# * You can submit your homework multiple times. In this case, only the last submission will be used.
#
# Deadline: 8 February (Wednesday), 22:00 CET

# %% [markdown]
# ## Solution
#
# We will publish the solution here
